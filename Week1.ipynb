# %%
a = "tidur"
print("kevin lagi",a)
# Out:
# kevin lagi tidur

# %%
b = ["david"]*2
b.append("top up")
b
# Out:
# ['david', 'david', 'top up']

# %%
b[-2:]
# Out:
# ['david', 'top up']

# %%
print("yang suka top up: " + b[1])
# Out:
# yang suka top up: david

# %%
print("sultan: {}".format(b[0]))
# Out:
# sultan: david

# %%
print("Nama : {}, \nTempat Tinggal : {} \nHobby :{}".format("david", "cikampek","buang-buang uang"))
# Out:
# Nama : david,
# Tempat Tinggal : cikampek
# Hobby :buang-buang uang

# %%
if 1>2:
    c = True
else:
    c = False
print("is david rich?",c)
# Out:
# is david rich? False
